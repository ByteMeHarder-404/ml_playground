# %%
import pathway as pw
from pathway.xpacks.llm.embedders import GeminiEmbedder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pathway as pw
# ----> 2 from pathway.xpacks.llm.embedders import GeminiEmbedder
#
# File c:\Users\Akshat Bhalani\AppData\Local\Programs\Python\Python311\Lib\site-packages\pathway\_stub_finder.py:13, in StubFinder.find_spec(self, fullname, path, target)
#      11     warning = pathway._warning()
#      12     error = error + "\n" + warning
# ---> 13     raise ModuleNotFoundError(error)
#      14 return None
#
# ModuleNotFoundError: No module named 'pathway.xpacks'
# This is not the real Pathway package.
# Visit https://pathway.com/developers/ to get Pathway.
# Already tried that? Visit https://pathway.com/troubleshooting/ to get help.
# Note: your platform is Windows-10-10.0.26100-SP0, your Python is CPython 3.11.4.
