# %%
from pyvirtualdisplay import Display
virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
import yaml

# %%
cnf='''SpaceInvadersNoFrameskip-v4:
  env_wrapper:
    - stable_baselines3.common.atari_wrappers.AtariWrapper
  frame_stack: 4
  policy: 'CnnPolicy'

  n_timesteps: 1000000   # keep it realistic

  buffer_size: 50000     # smaller but still usable
  learning_rate: !!float 1e-4
  batch_size: 32

  learning_starts: 10000  # faster start
  target_update_interval: 1000

  train_freq: 4
  gradient_steps: 1

  exploration_fraction: 0.2   # explore more early
  exploration_final_eps: 0.05 # higher than usual for faster learning

  optimize_memory_usage: False'''

# %%
with open("/kaggle/working/config.yaml", "w") as f:
    f.write(cnf)

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
import os

for root, dirs, files in os.walk("/kaggle/working"):
    for f in files:
        if f.endswith(".zip"):
            print(os.path.join(root, f))
# Out:
# /kaggle/working/logs/dqn/SpaceInvadersNoFrameskip-v4_1/best_model.zip
# /kaggle/working/logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# /kaggle/working/hub/spaceinvadersnoframeskip-v4/dqn-SpaceInvadersNoFrameskip-v4.zip
# /kaggle/working/hub/spaceinvadersnoframeskip-v4/train_eval_metrics.zip

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import VecVideoRecorder
from stable_baselines3.common.env_util import make_atari_env

env = make_atari_env("ALE/SpaceInvaders-v6", n_envs=1)

env = VecVideoRecorder(
    env,
    "/kaggle/working/videos/",
    record_video_trigger=lambda x: x == 0,
    video_length=500,
)

model = DQN.load("/kaggle/working/logs/dqn/SpaceInvadersNoFrameskip-v4_1/best_model.zip")

obs = env.reset()
for _ in range(500):
    action, _ = model.predict(obs)
    obs, _, _, _ = env.step(action)

env.close()
# Out:
# ---------------------------------------------------------------------------
# NamespaceNotFound                         Traceback (most recent call last)
# /tmp/ipykernel_55/1651868382.py in <cell line: 0>()
#       3 from stable_baselines3.common.env_util import make_atari_env
#       4
# ----> 5 env = make_atari_env("ALE/SpaceInvaders-v6", n_envs=1)
#       6
#       7 env = VecVideoRecorder(
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/env_util.py in make_atari_env(env_id, n_envs, seed, start_index, monitor_dir, wrapper_kwargs, env_kwargs, vec_env_cls, vec_env_kwargs, monitor_kwargs)
#     165     :return: The wrapped environment
#     166     """
# --> 167     return make_vec_env(
#     168         env_id,
#     169         n_envs=n_envs,
#
# ...
